# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import PIL
from PIL import Image
import os
import torchvision
from torchvision import transforms as tvt
import torch
from torch.nn import parallel
import torch.nn as nn
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
import pathlib
import random

# %%
count = 0
catNms=['airplane','bus','cat', 'dog', 'pizza']
for n, cat in enumerate(catNms):
    d = os.listdir('train/' + catNms[n])
    for i in range(0,1500):
        if i < 1500:
            temp_img = Image.open('train/' + catNms[n] + '/' + d[i])
            #print('img opened')
            np_arr = np.array(temp_img)
            if (np_arr.shape != (64, 64, 3)):
                print(len(np_arr.shape))

                print('bad shape')
                print('train/' + catNms[n] + '/' + d[i])
            #print(np_arr.shape[2])
            count = count+1

print(count)
# Out:
# 2
# bad shape
# train/airplane/COCO_train2014_000000166522.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000134071.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000066642.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000001350.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000033352.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000207339.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000107962.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000233263.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000018702.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000156878.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000221691.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000060060.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000249835.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000445845.jpg
# 2
# bad shape
# train/airplane/COCO_train2014_000000549879.jpg
# 2
# bad shape
# ...

# %%
index = 7499
print(index % 1500)
# Out:
# 1499
